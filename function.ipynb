# %%
def factorial():
  fact=1
  for i in range(1,6):
    fact=fact*i
  print(fact)
factorial()
# Out:
# 120

# %%
def sum(a,b):
  sum=a+b
  print(sum)
sum(5,8)
# Out:
# 13

# %%
def sum_avg():
  a=int(input('Enter 1st number : '))
  b=int(input('Enter 2nd number : '))
  sum=a+b
  avg=sum/2
  print('Sum = ',sum)
  print('Avarage = ',avg)
sum_avg()
# Out:
# Enter 1st number : 8
# Enter 2nd number : 2
# Sum =  10
# Avarage =  5.0
