# %%
set1={'red','black','rose','orange','pink'}
set1
# Out:
# {'black', 'orange', 'pink', 'red', 'rose'}

# %%
print(type(set1))
# Out:
# <class 'set'>

# %%
set2={2,4,5,7,2,5,2}
set2
# Out:
# {2, 4, 5, 7}

# %%
set2.add(500)
set2
# Out:
# {2, 4, 5, 7, 500}

# %%
set2.update(['hai'])

# %%
set2
# Out:
# {2, 4, 5, 500, 7, 'hai'}

# %%
5 in set2
# Out:
# True

# %%
8 in set2
# Out:
# False

# %%
set2.pop()
# Out:
# 2

# %%
set2.pop()
# Out:
# 4

# %%
set2
# Out:
# {5, 500, 7, 'hai'}

# %%
set2.remove('hai')

# %%
set2
# Out:
# {5, 7, 500}
