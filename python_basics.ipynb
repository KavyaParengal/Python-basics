# %%
string="hai"
print(string)
# Out:
# hai

# %%
x="10"
y=10

# %%
x
# Out:
# '10'

# %%
y
# Out:
# 10

# %%
print(type(x))
print(type(y))
# Out:
# <class 'str'>
# <class 'int'>

# %%
a=10
b=5
print('sum =',a+b)
print('multiplication =',a*b)
print('division =',a/b)
# Out:
# sum = 15
# multiplication = 50
# division = 2.0

# %%
a=int(input('Enter your 1st number ='))
b=int(input('Enter your 2nd number ='))
print('sum =',a+b)
# Out:
# Enter your 1st number =5
# Enter your 2nd number =7
# sum = 12

# %% [markdown]
# **data type**

# %%
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'int'>

# %% [markdown]
# **1.string length**

# %%
str1='hello'

# %%
print(len(str1))
# Out:
# 5

# %% [markdown]
# **2.Capitalize 1st letter**

# %%
str2='welcome to calicut university'

# %%
str2.capitalize()
# Out:
# 'Welcome to calicut university'

# %% [markdown]
# **3.capitalize 1st letters of each words**

# %%
str2.title()
# Out:
# 'Welcome To Calicut University'

# %% [markdown]
# **4.capitalize all letters**

# %%
str2.upper()
# Out:
# 'WELCOME TO CALICUT UNIVERSITY'

# %%
print(str2)
# Out:
# welcome to calicut university

# %%
str3='CALICUT UNIVERSITY'

# %% [markdown]
# **5.Lower the sentence**

# %%
str3.lower()
# Out:
# 'calicut university'

# %% [markdown]
# **6.count**

# %%
s1='i love apple, apple is my fav fruit'
s1.count('i')
# Out:
# 3

# %%
s1.count('l',1,18)
# Out:
# 3

# %% [markdown]
# **7.find**

# %%
s2='i love india'
s2.find('love')
# Out:
# 2

# %%
s1.find('e')
# Out:
# 5

# %%
s2.find('i',0,11)
# Out:
# 3

# %% [markdown]
# **8.index**

# %%
s1.index('love')
# Out:
# 2

# %%
s1.index('a')
# Out:
# 7

# %%
s1.index('o',2,27)
# Out:
# 3

# %% [markdown]
# **9.isalnum**

# %%
str3.isalnum()
# Out:
# False

# %%
x='kavya3108'
x.isalnum()
# Out:
# True

# %% [markdown]
# **10.isalpha**

# %%
str3.isalpha()
# Out:
# False

# %%
str4='HAI HELLO'
str4.isalpha()
# Out:
# False

# %%
x='kavya3108'
x.isalpha()
# Out:
# False

# %%
y='kavya'
y.isalpha()
# Out:
# True

# %% [markdown]
# **11.isdigit**

# %%
y='kavya23'

# %%
y.isdigit()
# Out:
# False

# %%
x='567'
x.isdigit()
# Out:
# True

# %% [markdown]
# **12.isspace**

# %%
y='kavya31'
y.isspace()
# Out:
# False

# %%
str4='CLT UCITY'
str4.isspace()
# Out:
# False

# %%
str5='hai'
str5.isspace()
# Out:
# False

# %%
str6=' welcome to calicut university '
str6.isspace()
# Out:
# False

# %% [markdown]
# **13.islower**

# %%
str6.islower()
# Out:
# True

# %%
str4.islower()
# Out:
# False

# %% [markdown]
# **14.isupper**

# %%
str4.isupper()
# Out:
# True

# %%
str6.isupper()
# Out:
# False

# %% [markdown]
# **15.istitle**

# %%
str7='Calicut University'
str7.istitle()
# Out:
# True

# %%
str6.istitle()
# Out:
# False

# %% [markdown]
# **16.strip**

# %%
str6.strip()
# Out:
# 'welcome to calicut university'

# %%
str7.strip()
# Out:
# 'Calicut University'

# %%
str6
# Out:
# ' welcome to calicut university '

# %%
str8='    hai   hello       world           '
print(str8)
print(str8.strip())
str8
# Out:
#     hai   hello       world
# hai   hello       world
# '    hai   hello       world           '

# %% [markdown]
# **17.partition**

# %%
str6.partition('to')
# Out:
# (' welcome ', 'to', ' calicut university ')

# %%
str6.partition('calicut')
# Out:
# (' welcome to ', 'calicut', ' university ')

# %% [markdown]
# **18.split**

# %%
str6.split()
# Out:
# ['welcome', 'to', 'calicut', 'university']

# %%
s1.split()
# Out:
# ['i', 'love', 'apple,', 'apple', 'is', 'my', 'fav', 'fruit']

# %% [markdown]
# **19.swapcase**

# %%
str6.swapcase()
# Out:
# ' WELCOME TO CALICUT UNIVERSITY '

# %%
str8.swapcase()
# Out:
# '    HAI   HELLO       WORLD           '

# %%
str4.swapcase()
# Out:
# 'clt ucity'

# %% [markdown]
# **20.join**

# %%
s2=' Hai Hello '
s2.join('2345')
# Out:
# '2 Hai Hello 3 Hai Hello 4 Hai Hello 5'

# %%
s2.join('kavya')
# Out:
# 'k Hai Hello a Hai Hello v Hai Hello y Hai Hello a'

# %% [markdown]
# **21.replace**

# %%
s3='i love my india !'
s3.replace('india','country')
# Out:
# 'i love my country !'
