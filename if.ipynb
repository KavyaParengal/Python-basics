# %%
a=10
b=20
if(a>b):
  print('a is greater than b')
else :
  print('b is greater than a')
# Out:
# b is greater than a

# %%
x=int(input('Enter a number : '))
if(x>0):
  print(x,' is positive')
elif(x<0):
  print(x,' is negative')
elif(x==0):
  print(x,' is zero')
else:
  print('Enter a valid number')
# Out:
# Enter a number : -2
# -2  is negative

# %%
a=int(input("Enter the 1st number : "))
b=int(input("Enter the 2nd number : "))
op=input("Enter the operation : ")
if(op=='+'):
  print(a,' + ',b, ' = ',a+b)
elif(op=='-'):
  print(a,' - ',b,' = ',a-b)
elif(op=='*'):
  print(a,' * ',b,' = ',a*b)
elif(op=='/'):
  print(a,' / ',b,' = ',a/b)
else:
  print('Enter an operation')
# Out:
# Enter the 1st number : 5
# Enter the 2nd number : 7
# Enter the operation : *
# 5  *  7  =  35

# %%
billamt=int(input(" Enter the bill amount : "))
if(billamt<1500):
  print('Pay the bill amount ',billamt)
elif(billamt>=1500):
  dis=1500*(10/100)
  bill=billamt-dis
  print('Pay the bill amount ',bill)
# Out:
#  Enter the bill amount : 1432
# Pay the bill amount  1432

# %%
x=int(input('Enter a number : '))
if(x%2==0):
  print(x,' is even .')
else:
  print(x,' is odd .')
# Out:
# Enter a number : 5
# 5  is odd .
