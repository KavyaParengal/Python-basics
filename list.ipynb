# %%
x=[1,2,3,'hello','hai']
print(type(x))
# Out:
# <class 'list'>

# %%
x
# Out:
# [1, 2, 3, 'hello', 'hai']

# %%
print(x[1])
# Out:
# 2

# %%
print(x[0])
# Out:
# 1

# %%
x[0]
# Out:
# 1

# %%
x[:3]
# Out:
# [1, 2, 3]

# %%
x[3:]
# Out:
# ['hello', 'hai']

# %%
x[4:]
# Out:
# ['hai']

# %%
x[:4]
# Out:
# [1, 2, 3, 'hello']

# %%
x[6:]
# Out:
# []

# %%
y=['mango','orange','banana','car','jeep',]
y[-1]
# Out:
# 'jeep'

# %%
y[-2]
# Out:
# 'car'

# %%
y[-5]
# Out:
# 'mango'

# %%
y[1]='red'

# %%
y
# Out:
# ['mango', 'red', 'banana', 'car', 'jeep']

# %%
y.append('rose')

# %%
y
# Out:
# ['mango', 'red', 'banana', 'car', 'jeep', 'rose', 'rose']

# %%
y.insert(2,'black')

# %%
y
# Out:
# ['mango', 'red', 'black', 'banana', 'car', 'jeep', 'rose', 'rose']

# %%
y.extend(['hai','hello',3,4])

# %%
y
# Out:
# ['mango',
#  'red',
#  'black',
#  'banana',
#  'car',
#  'jeep',
#  'rose',
#  'rose',
#  'hai',
#  'hello',
#  3,
#  4]

# %%
y.pop()
y
# Out:
# ['mango', 'black', 'banana', 'car', 'jeep', 'rose', 'rose', 'hai', 'hello']

# %%
y.remove('car')

# %%
y
# Out:
# ['mango',
#  'black',
#  'banana',
#  'car',
#  'jeep',
#  'rose',
#  'rose',
#  'hai',
#  'hello',
#  3,
#  4]

# %%
y.reverse()

# %%
y
# Out:
# ['mango',
#  'black',
#  'banana',
#  'car',
#  'jeep',
#  'rose',
#  'rose',
#  'hai',
#  'hello',
#  3,
#  4]

# %%
y.sort()

# %%
y
# Out:
# ['banana', 'black', 'hai', 'hello', 'jeep', 'mango', 'rose', 'rose']
