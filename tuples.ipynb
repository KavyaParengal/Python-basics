# %%
x=()

# %%
print(type(x))
# Out:
# <class 'tuple'>

# %%
y=[1,3,5,'hai']

# %%
z=tuple(y)

# %%
z
# Out:
# (1, 3, 5, 'hai')

# %%
print(type(z))
# Out:
# <class 'tuple'>

# %%
print(z[-2:-4])
# Out:
# ()

# %%
print(z[1:4])
# Out:
# (3, 5, 'hai')

# %%
print(z[2])
# Out:
# 5

# %%
print(z[-1])
# Out:
# hai

# %%
print(z[-4:-1])
# Out:
# (1, 3, 5)

# %%
if 'hai' in z:
  print('yes , item exist')
# Out:
# yes , item exist

# %%
y=list(z)

# %%
y
# Out:
# [1, 3, 5, 'hai']

# %%
y[2]='hello'

# %%
y
# Out:
# [1, 3, 'hello', 'hai']

# %%
z=tuple(y)

# %%
z
# Out:
# (1, 3, 'hello', 'hai')

# %%
y.remove(1)

# %%
y
# Out:
# [3, 'hello', 'hai']

# %%
z=tuple(y)

# %%
z
# Out:
# (3, 'hello', 'hai')

# %%
x=('red','black','rose')

# %%
z+x
# Out:
# (3,
#  'hello',
#  'hai',
#  'red',
#  'black',
#  'rose',
#  'red',
#  'black',
#  'rose',
#  'red',
#  'black',
#  'rose')

# %%
z
# Out:
# (3, 'hello', 'hai', 'red', 'black', 'rose', 'red', 'black', 'rose')

# %%
del x

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-6fcf9dfbd479> in <module>
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
tuple1=(23,45,6)
a,b,c=tuple1
a
# Out:
# 23

# %%
a=40
tuple1=a,b,c
tuple1
# Out:
# (40, 45, 6)

# %%
t2='hai'
t2*3
# Out:
# 'haihaihai'

# %%
a=(20,30)
b=(30,50)
a==b
# Out:
# False

# %%
a>b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
print(len(tuple1))
# Out:
# 3

# %%
t1=(100,200,300,300)
max(t1)
# Out:
# 300

# %%
min(t1)
# Out:
# 100

# %%
t1.count(300)
# Out:
# 2
