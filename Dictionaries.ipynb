# %%
std={
    'roll no':101,
    'name':'kavya',
     "age":21,
     'course':'msc cs',
     'address':'parengal house'
}

# %%
print(type(std))
# Out:
# <class 'dict'>

# %%
std
# Out:
# {'roll no': 101,
#  'name': 'kavya',
#  'age': 21,
#  'course': 'msc cs',
#  'address': 'parengal house'}

# %%
std['name']
# Out:
# 'kavya'

# %%
std['age']=22

# %%
std
# Out:
# {'roll no': 101,
#  'name': 'kavya',
#  'age': 22,
#  'course': 'msc cs',
#  'address': 'parengal house'}

# %%
std['college']='ccsit cu campus'

# %%
std
# Out:
# {'roll no': 101,
#  'name': 'kavya',
#  'age': 22,
#  'course': 'msc cs',
#  'address': 'parengal house',
#  'college': 'ccsit cu campus'}

# %%
del std['age']

# %%
std
# Out:
# {'roll no': 101,
#  'name': 'kavya',
#  'course': 'msc cs',
#  'address': 'parengal house',
#  'college': 'ccsit cu campus'}

# %%
std.clear()

# %%
std
# Out:
# {}

# %%
del std

# %%
std
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-60449bf8eec6> in <module>
# ----> 1 std
#
# NameError: name 'std' is not defined
